# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# Load previously cleaned csv file
# Output column is the output based on previously created buckets
df = pd.read_csv(r'C:\Rohan\College\1st Year\Spring Quarter\Misc\Datathon\Datathon Dataset\Cleaned_Data.csv')

pd.set_option('display.max_columns', None)
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 0        149190     55629189        Caucasian  Female  [10-20)
# 1         64410     86047875  AfricanAmerican  Female  [20-30)
# 2        500364     82442376        Caucasian    Male  [30-40)
# 3         16680     42519267        Caucasian    Male  [40-50)
# 4         35754     82637451        Caucasian    Male  [50-60)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  1                         1                    7
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  2                         1                    2
#
#    time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# 0                 3                  59               0               18
# ...

# %%
pd.crosstab(df.admission_type_id, df.output, margins=True)
# Out:
# output                 0      1     2      3      4     5     All
# admission_type_id
# 1                  16400  11673  2998  11552   7449  3160   53232
# 2                   6320   4010  1126   3432   2388   927   18203
# 3                   6986   3533   959   3957   2133   977   18545
# 4                      5      1     0      2      1     1      10
# 5                   1051    607   163   1475   1093   330    4719
# 6                   1320   1331   265   1095    871   317    5199
# 7                      5      0     0     16      0     0      21
# 8                    165     66    21     40     17     6     315
# All                32252  21221  5532  21569  13952  5718  100244

# %%
import scipy
from scipy.stats import chi2_contingency

ct = pd.crosstab(df.admission_type_id, df.output, margins=True)
row_sum = ct.iloc[0:8,6].values
exp = []
for j in range(8):
    for val in ct.iloc[8,0:6].values:
        exp.append(val * row_sum[j] / ct.loc['All', 'All'])

for i in range(6):
    

((obs - exp)**2/exp).sum()
scipy.stats.chi2_contingency(obs)[0:3]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Rohan\College\1st Year\Spring Quarter\Misc\Datathon\Code\Repository Code\west-coast-datathon\chi.ipynb Cell 3' in <cell line: 11>()
#       <a href='vscode-notebook-cell:/c%3A/Rohan/College/1st%20Year/Spring%20Quarter/Misc/Datathon/Code/Repository%20Code/west-coast-datathon/chi.ipynb#ch0000004?line=7'>8</a>     for val in ct.iloc[8,0:6].values:
#       <a href='vscode-notebook-cell:/c%3A/Rohan/College/1st%20Year/Spring%20Quarter/Misc/Datathon/Code/Repository%20Code/west-coast-datathon/chi.ipynb#ch0000004?line=8'>9</a>         exp.append(val * row_sum[j] / ct.loc['All', 'All'])
# ---> <a href='vscode-notebook-cell:/c%3A/Rohan/College/1st%20Year/Spring%20Quarter/Misc/Datathon/Code/Repository%20Code/west-coast-datathon/chi.ipynb#ch0000004?line=10'>11</a> ((obs - exp)**2/exp).sum()
# ...
